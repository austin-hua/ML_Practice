# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import matplotlib as mpl

# %%
mpl.rc('font', family='Noto Sans CJK TC')

# %%
df = pd.read_csv('https://stats.moe.gov.tw/files/detail/107/107_student.csv')

# %%
df.head()
# Out:
#              大專校院校別學生數 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  107 學年度 SY2018-2019        NaN        NaN        NaN        NaN        NaN
# 1                 學校代碼       學校名稱     日間∕進修別        等級別         總計        男生計
# 2                 0001     國立政治大學        D 日       D 博士        965        551
# 3                 0001     國立政治大學        D 日       M 碩士      3,998      1,854
# 4                 0001     國立政治大學        D 日       B 學士      9,630      3,983
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        女生計      一年級男生      一年級女生      二年級男生  ...       五年級男生       五年級女生
# 2        414         96         85         82  ...          71          52
# 3      2,144        624        742        632  ...           -           -
# 4      5,647        899      1,287        890  ...           -           -
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1       六年級男生       六年級女生       七年級男生       七年級女生       延修生男生       延修生女生
# 2          58          46          74          40           -           -
# 3           -           -           -           -           -           -
# 4           -           -           -           -         326         463
#
#   Unnamed: 23 Unnamed: 24
# 0         NaN         NaN
# 1        縣市名稱         體系別
# 2      30 臺北市        1 一般
# 3      30 臺北市        1 一般
# 4      30 臺北市        1 一般
#
# [5 rows x 25 columns]

# %%
colnames = df.loc[1].values

# %%
df = df[2:]

# %%
df.columns = colnames

# %%
df.head()
# Out:
#    學校代碼    學校名稱 日間∕進修別   等級別     總計    男生計    女生計 一年級男生  一年級女生 二年級男生  ...  \
# 2  0001  國立政治大學    D 日  D 博士    965    551    414    96     85    82  ...
# 3  0001  國立政治大學    D 日  M 碩士  3,998  1,854  2,144   624    742   632  ...
# 4  0001  國立政治大學    D 日  B 學士  9,630  3,983  5,647   899  1,287   890  ...
# 5  0001  國立政治大學    N 職  M 碩士  1,750    896    854   303    248   253  ...
# 6  0002  國立清華大學    D 日  D 博士  1,664  1,221    443   225     99   201  ...
#
#   五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 2    71    52    58    46    74    40     -     -  30 臺北市  1 一般
# 3     -     -     -     -     -     -     -     -  30 臺北市  1 一般
# 4     -     -     -     -     -     -   326   463  30 臺北市  1 一般
# 5    53    47     -     -     -     -     -     -  30 臺北市  1 一般
# 6   158    50   112    43   168    58     -     -  18 新竹市  1 一般
#
# [5 rows x 25 columns]

# %%
colnames
# Out:
# array(['學校代碼', '學校名稱', '日間∕進修別', '等級別', '總計', '男生計', '女生計', '一年級男生',
#        '一年級女生', '二年級男生', '二年級女生', '三年級男生', '三年級女生', '四年級男生', '四年級女生',
#        '五年級男生', '五年級女生', '六年級男生', '六年級女生', '七年級男生', '七年級女生', '延修生男生',
#        '延修生女生', '縣市名稱', '體系別'], dtype=object)

# %%
undergraduate = df[(df['日間∕進修別'] == 'D 日') & (df['等級別'] == 'B 學士')]

# %%
undergraduate.head()
# Out:
#     學校代碼      學校名稱 日間∕進修別   等級別      總計    男生計    女生計  一年級男生  一年級女生  二年級男生  \
# 4   0001    國立政治大學    D 日  B 學士   9,630  3,983  5,647    899  1,287    890
# 8   0002    國立清華大學    D 日  B 學士   8,689  4,696  3,993  1,089    865  1,087
# 13  0003    國立臺灣大學    D 日  B 學士  16,604  9,447  7,157  2,126  1,525  2,110
# 17  0004  國立臺灣師範大學    D 日  B 學士   8,079  3,583  4,496    846  1,066    850
# 21  0005    國立成功大學    D 日  B 學士  11,390  7,123  4,267  1,672  1,010  1,651
#
#     ... 五年級男生 五年級女生 六年級男生 六年級女生 七年級男生 七年級女生 延修生男生 延修生女生    縣市名稱   體系別
# 4   ...     -     -     -     -     -     -   326   463  30 臺北市  1 一般
#
# 320       世新大學    D 日  B 學士   9,671  3,409   6,262    823  1,489
# 326       銘傳大學    D 日  B 學士  17,333  6,868  10,465  1,664  2,520
# 330       實踐大學    D 日  B 學士  11,258  3,713   7,545    807  1,903
# 342     高雄醫學大學    D 日  B 學士   5,546  2,445   3,101    481    738
# 347       南華大學    D 日  B 學士   4,489  2,160   2,329    647    701
# 351       真理大學    D 日  B 學士   5,830  2,834   2,996    676    846
# 356       大同大學    D 日  B 學士   3,689  2,226   1,463    535    353
# 389       慈濟大學    D 日  B 學士   2,968  1,148   1,820    264    435
# 393     臺北醫學大學    D 日  B 學士   4,733  1,986   2,747    357    575
# 399     中山醫學大學    D 日  B 學士   6,099  2,355   3,744    461    875
# 427       長榮大學    D 日  B 學士   8,210  3,594   4,616    766  1,206
# 441     中國醫藥大學    D 日  B 學士   6,420  2,866   3,554    515    725
# 466       玄奘大學    D 日  B 學士   2,859  1,186   1,673    194    334
# 518       亞洲大學    D 日  B 學士   9,616  3,524   6,092    825  1,509
# 522       開南大學    D 日  B 學士   5,119  2,508   2,611    583    550
# 527       佛光大學    D 日  B 學士   2,970  1,380   1,590    320    425
# 576       明道大學    D 日  B 學士   2,819  1,608   1,211    385    272
# 625     台灣首府大學    D 日  B 學士   1,758    877     881    220    208
# 697       康寧大學    D 日  B 學士     607    287     320     30     85
# 730   中信金融管理學院    D 日  B 學士     588    292     296    113     84
# 755  稻江科技暨管理學院    D 日  B 學士   1,455    773     682    231    229
# 788      馬偕醫學院    D 日  B 學士     661    254     407     48    111
# 791     法鼓文理學院    D 日  B 學士      57     21      36      4     11
# 812     臺北市立大學    D 日  B 學士   5,304   2373   2,931    566    725
#
# [70 rows x 8 columns]

# %%
df2 = undergraduate.loc[:,'學校名稱':'女生計'].copy()

# %%
#df2.女生計 / df2.男生計

# %%
df2.head()
# Out:
#         學校名稱 日間∕進修別   等級別      總計    男生計    女生計
# 4     國立政治大學    D 日  B 學士   9,630  3,983  5,647
# 8     國立清華大學    D 日  B 學士   8,689  4,696  3,993
# 13    國立臺灣大學    D 日  B 學士  16,604  9,447  7,157
# 17  國立臺灣師範大學    D 日  B 學士   8,079  3,583  4,496
# 21    國立成功大學    D 日  B 學士  11,390  7,123  4,267

# %%
import locale

#atof

# %%
locale.setlocale(locale.LC_NUMERIC, '')
# Out:
# 'C'

# %%
#df2['男生計'] = df2['男生計'].apply(locale.atof)

# %%
#df2['女生計'] = df2['女生計'].apply(locale.atof)

# %%
#df2['女男比例'] = df.女生計 / df.男生計

# %%
#df2.head()

# %%
#df3 = df2.sort_values(by = ['女男比例'], ascending = False)

# %%
#df3[:20].plot.bar(x='學校名稱', y=['女男比例'])

# %%
#df = pd.read_html('https://browser.geekbench.com/mac-benchmarks')

# %%
#len(df)

# %%
#mac = df[0]

# %%
#mac.head()

# %%
#mac[mac.Mac.str.contains('Mid 2018')]

# %%
#mac[mac.Score > 5347]

# %%
df = pd.read_html('http://www.9800.com.tw/statistics/asp')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-31-08bc6c41abf2> in <module>
# ----> 1 df = pd.read_html('http://www.9800.com.tw/statistics/asp')
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1092                   decimal=decimal, converters=converters, na_values=na_values,
#    1093                   keep_default_na=keep_default_na,
# -> 1094                   displayed_only=displayed_only)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     914             break
#     915     else:
# --> 916         raise_with_traceback(retained)
#     917
#     918     ret = []
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     418         if traceback == Ellipsis:
#     419             _, _, traceback = sys.exc_info()
# --> 420         raise exc.with_traceback(traceback)
#     421 else:
#     422     # this version of raise is a syntax error in Python 3
#
# HTTPError: HTTP Error 404: Not Found
